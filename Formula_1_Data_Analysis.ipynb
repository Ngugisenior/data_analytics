# %% [markdown]
# <a href="https://colab.research.google.com/github/Ngugisenior/data_analytics/blob/main/Formula_1_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Libraries

# %%
import requests
import json 
import pandas as pd 

from bokeh.io import output_notebook, show
output_notebook()
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.plotting import figure
from bokeh.sampledata.autompg import autompg_clean as df
from bokeh.transform import factor_cmap

# Use 3 decimal places in output display
pd.set_option("display.precision", 3)

# Don't wrap repr(DataFrame) across additional lines
pd.set_option("display.expand_frame_repr", False)

# Set max rows displayed in output to 25
pd.set_option("display.max_rows", 2505)

# %% [markdown]
# Request Racing Data from API

# %%
def get_drivers_data(limit=None,series=None,offset=None,total=None,data=None):
  limit = '?limit={}'.format(limit) if limit else ''
  url = 'https://ergast.com/api/f1.json{}'.format(limit)
  req = requests.get(url)

  response = req.json()
  return response
racing_data = get_drivers_data()
pd.json_normalize(racing_data)
limit = racing_data['MRData']['total']

# %% [markdown]
# Circuits By Year

# %%
circuits = get_drivers_data(limit=2000)['MRData']['RaceTable']['Races']
circuits = pd.DataFrame(pd.json_normalize(circuits))
circuits.to_csv('Formula 1 Historical Data.csv')

# %% [markdown]
# Circuits in 1950

# %%
cr_1950 = circuits.loc[circuits['season']=='1950']
cr_1950.sort_values(by='date').reset_index(drop=True)
# Out:
#   season round                                                url            raceName        date Circuit.circuitId                                        Circuit.url           Circuit.circuitName Circuit.Location.lat Circuit.Location.long Circuit.Location.locality Circuit.Location.country time
# 0   1950     1  http://en.wikipedia.org/wiki/1950_British_Gran...  British Grand Prix  1950-05-13       silverstone   http://en.wikipedia.org/wiki/Silverstone_Circuit           Silverstone Circuit              52.0786              -1.01694               Silverstone                       UK  NaN
# 1   1950     2  http://en.wikipedia.org/wiki/1950_Monaco_Grand...   Monaco Grand Prix  1950-05-21            monaco     http://en.wikipedia.org/wiki/Circuit_de_Monaco             Circuit de Monaco              43.7347               7.42056               Monte-Carlo                   Monaco  NaN
# 2   1950     3  http://en.wikipedia.org/wiki/1950_Indianapolis...    Indianapolis 500  1950-05-30      indianapolis  http://en.wikipedia.org/wiki/Indianapolis_Moto...   Indianapolis Motor Speedway               39.795              -86.2347              Indianapolis                      USA  NaN
# 3   1950     4  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...    Swiss Grand Prix  1950-06-04        bremgarten    http://en.wikipedia.org/wiki/Circuit_Bremgarten            Circuit Bremgarten              46.9589               7.40194                      Bern              Switzerland  NaN
# 4   1950     5  http://en.wikipedia.org/wiki/1950_Belgian_Gran...  Belgian Grand Prix  1950-06-18               spa  http://en.wikipedia.org/wiki/Circuit_de_Spa-Fr...  Circuit de Spa-Francorchamps              50.4372               5.97139                       Spa                  Belgium  NaN
# 5   1950     6  http://en.wikipedia.org/wiki/1950_French_Grand...   French Grand Prix  1950-07-02             reims           http://en.wikipedia.org/wiki/Reims-Gueux                   Reims-Gueux              49.2542               3.93083                     Reims                   France  NaN
# 6   1950     7  http://en.wikipedia.org/wiki/1950_Italian_Gran...  Italian Grand Prix  1950-09-03             monza  http://en.wikipedia.org/wiki/Autodromo_Naziona...  Autodromo Nazionale di Monza              45.6156               9.28111                     Monza                    Italy  NaN

# %% [markdown]
# Most Used circuit in F1

# %%
# Group circults by circuit name and country name
cr_cname = circuits.groupby( [ 'Circuit.circuitName','Circuit.Location.country'] ).size()

# Transform Grouping into a DataFrame
cr_cname = pd.DataFrame({'count' : cr_cname})

# Sort the result set
cr_cname = cr_cname.sort_values(by='count', ascending=False)
# Reset the index
cr_cname.reset_index()
# Out:
#                       Circuit.circuitName Circuit.Location.country  count
# 0            Autodromo Nazionale di Monza                    Italy     68
# 1                       Circuit de Monaco                   Monaco     65
# 2                     Silverstone Circuit                       UK     52
# 3            Circuit de Spa-Francorchamps                  Belgium     51
# 4                             Nürburgring                  Germany     40
# 5               Circuit Gilles Villeneuve                   Canada     39
# 6                          Hockenheimring                  Germany     36
# 7              Autódromo José Carlos Pace                   Brazil     36
# 8                             Hungaroring                  Hungary     33
# 9                          Suzuka Circuit                    Japan     30
# 10                 Circuit Park Zandvoort              Netherlands     30
# 11         Circuit de Barcelona-Catalunya                    Spain     28
# 12          Autodromo Enzo e Dino Ferrari                    Italy     27
# 13                                A1-Ring                  Austria     25
# 14         Albert Park Grand Prix Circuit                Australia     24
# 15                           Watkins Glen                      USA     20
# 16          Autódromo Juan y Oscar Gálvez                Argentina     20
# 17                                Kyalami             South Africa     20
# 18           Sepang International Circuit                 Malaysia     19
# 19            Indianapolis Motor Speedway                      USA     19
# 20           Autódromo Hermanos Rodríguez                   Mexico     19
# 21          Circuit de Nevers Magny-Cours                   France     18
# 22         Shanghai International Circuit                    China     16
# 23          Bahrain International Circuit                  Bahrain     15
# 24                    Circuit Paul Ricard                   France     15
# 25                           Brands Hatch                       UK     14
# 26                   Autódromo do Estoril                 Portugal     13
# 27                            Reims-Gueux                   France     11
# 28              Marina Bay Street Circuit                Singapore     11
# 29                Adelaide Street Circuit                Australia     11
# 30                                 Zolder                  Belgium     10
# 31  Autódromo Internacional Nelson Piquet                   Brazil     10
# 32                     Yas Marina Circuit                      UAE     10
# 33                                 Jarama                    Spain      9
# 34          Mosport International Raceway                   Canada      8
# 35                             Long Beach                      USA      8
# 36                          Istanbul Park                   Turkey      7
# 37                 Detroit Street Circuit                      USA      7
# 38                Circuit of the Americas                      USA      7
# 39                      Circuito de Jerez                    Spain      7
# 40                          Dijon-Prenois                   France      6
# 41                   Scandinavian Raceway                   Sweden      6
# 42                Valencia Street Circuit                    Spain      5
# 43                     Circuit Bremgarten              Switzerland      5
# 44                      Rouen-Les-Essarts                   France      5
# 45                         Sochi Autodrom                   Russia      5
# 46                                Aintree                       UK      5
# 47                          Red Bull Ring                  Austria      5
# 48           Korean International Circuit                    Korea      4
# 49                          Fuji Speedway                    Japan      4
# 50                        Charade Circuit                   France      4
# 51                               Montjuïc                    Spain      4
# 52                 Phoenix street circuit                      USA      3
# 53                  Prince George Circuit             South Africa      3
# 54                      Baku City Circuit               Azerbaijan      3
# 55            Buddh International Circuit                    India      3
# 56               Las Vegas Street Circuit                      USA      2
# 57                       Nivelles-Baulers                  Belgium      2
# 58                 Circuit Mont-Tremblant                   Canada      2
# 59                   Circuit de Pedralbes                    Spain      2
# 60                   Circuito da Boavista                 Portugal      2
# 61          Okayama International Circuit                    Japan      2
# 62                         Donington Park                       UK      1
# 63                                Zeltweg                  Austria      1
# 64                        Pescara Circuit                    Italy      1
# 65                               Ain Diab                  Morocco      1
# 66                                   AVUS                  Germany      1
# 67          Sebring International Raceway                      USA      1
# 68                                Le Mans                   France      1
# 69                  Monsanto Park Circuit                 Portugal      1
# 70        Riverside International Raceway                      USA      1
# 71                              Fair Park                      USA      1

# %% [markdown]
# Country That has hosted most F1 Races

# %%
# Group circults by country name
cr_country = circuits.groupby( [ 'Circuit.Location.country'] ).size()

# Transform Grouping into a DataFrame
cr_country = pd.DataFrame({'# Races' : cr_country})

# Sort the result set
cr_country = cr_country.sort_values(by='# Races', ascending=False)
# Reset the index
cr_country = cr_country.reset_index()
cr_country
# Out:
#    Circuit.Location.country  # Races
# 0                     Italy       96
# 1                   Germany       77
# 2                        UK       72
# 3                       USA       69
# 4                    Monaco       65
# 5                   Belgium       63
# 6                    France       60
# 7                     Spain       55
# 8                    Canada       49
# 9                    Brazil       46
# 10                    Japan       36
# 11                Australia       35
# 12                  Hungary       33
# 13                  Austria       31
# 14              Netherlands       30
# 15             South Africa       23
# 16                Argentina       20
# 17                   Mexico       19
# 18                 Malaysia       19
# 19                 Portugal       16
# 20                    China       16
# 21                  Bahrain       15
# 22                Singapore       11
# 23                      UAE       10
# 24                   Turkey        7
# 25                   Sweden        6
# 26                   Russia        5
# 27              Switzerland        5
# 28                    Korea        4
# 29                    India        3
# 30               Azerbaijan        3
# 31                  Morocco        1

# %%
c_list = cr_country['Circuit.Location.country'].tolist()
c_count = cr_country['# Races'].tolist()

# %%
p = figure(plot_width=1200, plot_height=500, title="Formula 1",
           x_range=c_list, toolbar_location=None, tools="")

p.vbar(x=c_list, top=c_count, width=0.9)

p.xgrid.grid_line_color = None
p.y_range.start = 0

show(p)
# Out:
#   <div class="bk-root" id="93f9be9c-be4e-43d6-ab8c-319851d08830" data-root-id="2096"></div>

# %%
driver_table = response['MRData']['DriverTable']
driver_table
# Out:
# {'Drivers': [{'dateOfBirth': '1932-07-10',
#    'driverId': 'abate',
#    'familyName': 'Abate',
#    'givenName': 'Carlo',
#    'nationality': 'Italian',
#    'url': 'http://en.wikipedia.org/wiki/Carlo_Mario_Abate'},
#   {'dateOfBirth': '1913-03-21',
#    'driverId': 'abecassis',
#    'familyName': 'Abecassis',
#    'givenName': 'George',
#    'nationality': 'British',
#    'url': 'http://en.wikipedia.org/wiki/George_Abecassis'},
#   {'dateOfBirth': '1957-11-27',
#    'driverId': 'acheson',
#    'familyName': 'Acheson',
#    'givenName': 'Kenny',
#    'nationality': 'British',
#    'url': 'http://en.wikipedia.org/wiki/Kenny_Acheson'},
#   {'dateOfBirth': '1969-11-19',
#    'driverId': 'adams',
#    'familyName': 'Adams',
#    'givenName': 'Philippe',
#    'nationality': 'Belgian',
#    'url': 'http://en.wikipedia.org/wiki/Philippe_Adams'},
#   {'dateOfBirth': '1913-12-15',
#    'driverId': 'ader',
#    'familyName': 'Ader',
#    'givenName': 'Walt',
#    'nationality': 'American',
#    'url': 'http://en.wikipedia.org/wiki/Walt_Ader'},
#   {'dateOfBirth': '1921-11-05',
#    'driverId': 'adolff',
#    'familyName': 'Adolff',
#    'givenName': 'Kurt',
#    'nationality': 'German',
#    'url': 'http://en.wikipedia.org/wiki/Kurt_Adolff'},
#   {'dateOfBirth': '1913-08-21',
#    'driverId': 'agabashian',
#    'familyName': 'Agabashian',
#    'givenName': 'Fred',
#    'nationality': 'American',
#    'url': 'http://en.wikipedia.org/wiki/Fred_Agabashian'},
#   {'dateOfBirth': '1940-04-19',
#    'driverId': 'ahrens',
#    'familyName': 'Ahrens',
#    'givenName': 'Kurt',
#    'nationality': 'German',
#    'url': 'http://en.wikipedia.org/wiki/Kurt_Ahrens,_Jr.'},
#   {'code': 'AIT',
#    'dateOfBirth': '1995-09-23',
#    'driverId': 'aitken',
#    'familyName': 'Aitken',
#    'givenName': 'Jack',
#    'nationality': 'British',
#    'permanentNumber': '89',
#    'url': 'http://en.wikipedia.org/wiki/Jack_Aitken'},
#   {'code': 'ALB',
#    'dateOfBirth': '1979-04-16',
#    'driverId': 'albers',
#    'familyName': 'Albers',
#    'givenName': 'Christijan',
#    'nationality': 'Dutch',
#    'url': 'http://en.wikipedia.org/wiki/Christijan_Albers'},
#   {'code': 'ALB',
#    'dateOfBirth': '1996-03-23',
#    'driverId': 'albon',
#    'familyName': 'Albon',
#    'givenName': 'Alexander',
#    'nationality': 'Thai',
#    'permanentNumber': '23',
#    'url': 'http://en.wikipedia.org/wiki/Alexander_Albon'},
#   {'dateOfBirth': '1956-12-23',
#    'driverId': 'alboreto',
#    'familyName': 'Alboreto',
#    'givenName': 'Michele',
#    'nationality': 'Italian',
#    'url': 'http://en.wikipedia.org/wiki/Michele_Alboreto'},
#   {'dateOfBirth': '1964-06-11',
#    'driverId': 'alesi',
#    'familyName': 'Alesi',
#    'givenName': 'Jean',
#    'nationality': 'French',
#    'url': 'http://en.wikipedia.org/wiki/Jean_Alesi'},
#   {'code': 'ALG',
#    'dateOfBirth': '1990-03-23',
#    'driverId': 'alguersuari',
#    'familyName': 'Alguersuari',
#    'givenName': 'Jaime',
#    'nationality': 'Spanish',
#    'url': 'http://en.wikipedia.org/wiki/Jaime_Alguersuari'},
#   {'dateOfBirth': '1954-07-27',
#    'driverId': 'alliot',
#    'familyName': 'Alliot',
#    'givenName': 'Philippe',
#    'nationality': 'French',
#    'url': 'http://en.wikipedia.org/wiki/Philippe_Alliot'},
#   {'dateOfBirth': '1932-02-08',
#    'driverId': 'allison',
#    'familyName': 'Allison',
#    'givenName': 'Cliff',
#    'nationality': 'British',
#    'url': 'http://en.wikipedia.org/wiki/Cliff_Allison'},
#   {'code': 'ALO',
#    'dateOfBirth': '1981-07-29',
#    'driverId': 'alonso',
#    'familyName': 'Alonso',
#    'givenName': 'Fernando',
#    'nationality': 'Spanish',
#    'permanentNumber': '14',
#    'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso'},
#   {'dateOfBirth': '1959-07-20',
#    'driverId': 'amati',
#    'familyName': 'Amati',
#    'givenName': 'Giovanna',
#    'nationality': 'Italian',
#    'url': 'http://en.wikipedia.org/wiki/Giovanna_Amati'},
#   {'dateOfBirth': '1929-01-19',
#    'driverId': 'amick',
#    'familyName': 'Amick',
#    'givenName': 'Red',
#    'nationality': 'American',
#    'url': 'http://en.wikipedia.org/wiki/Red_Amick'},
#   {'dateOfBirth': '1924-10-24',
#    'driverId': 'george_amick',
#    'familyName': 'Amick',
#    'givenName': 'George',
#    'nationality': 'American',
#    'url': 'http://en.wikipedia.org/wiki/George_Amick'},
#   {'dateOfBirth': '1943-07-20',
#    'driverId': 'amon',
#    'familyName': 'Amon',
#    'givenName': 'Chris',
#    'nationality': 'New Zealander',
#    'url': 'http://en.wikipedia.org/wiki/Chris_Amon'},
#   {'dateOfBirth': '1931-05-19',
#    'driverId': 'anderson',
#    'familyName': 'Anderson',
#    'givenName': 'Bob',
#    'nationality': 'British',
#    'url': 'http://en.wikipedia.org/wiki/Bob_Anderson_(racing_driver)'},
#   {'dateOfBirth': '1939-12-28',
#    'driverId': 'andersson',
#    'familyName': 'Andersson',
#    'givenName': 'Conny',
#    'nationality': 'Swedish',
#    'url': 'http://en.wikipedia.org/wiki/Conny_Andersson_(racing_driver)'},
#   {'dateOfBirth': '1962-10-05',
#    'driverId': 'andretti',
#    'familyName': 'Andretti',
#    'givenName': 'Michael',
#    'nationality': 'American',
#    'url': 'http://en.wikipedia.org/wiki/Michael_Andretti'},
#   {'dateOfBirth': '1940-02-28',
#    'driverId': 'mario_andretti',
#    'familyName': 'Andretti',
#    'givenName': 'Mario',
#    'nationality': 'American',
#    'url': 'http://en.wikipedia.org/wiki/Mario_Andretti'},
#   {'dateOfBirth': '1920-06-15',
#    'driverId': 'andrews',
#    'familyName': 'Andrews',
#    'givenName': 'Keith',
#    'nationality': 'American',
#    'url': 'http://en.wikipedia.org/wiki/Keith_Andrews_(driver)'},
#   {'dateOfBirth': '1965-10-07',
#    'driverId': 'apicella',
#    'familyName': 'Apicella',
#    'givenName': 'Marco',
#    'nationality': 'Italian',
#    'url': 'http://en.wikipedia.org/wiki/Marco_Apicella'},
#   {'dateOfBirth': '1918-10-12',
#    'driverId': 'armi',
#    'familyName': 'Armi',
#    'givenName': 'Frank',
#    'nationality': 'American',
#    'url': 'http://en.wikipedia.org/wiki/Frank_Armi'},
#   {'dateOfBirth': '1926-05-30',
#    'driverId': 'arnold',
#    'familyName': 'Arnold',
#    'givenName': 'Chuck',
#    'nationality': 'American',
#    'url': 'http://en.wikipedia.org/wiki/Chuck_Arnold'},
#   {'dateOfBirth': '1948-07-04',
#    'driverId': 'arnoux',
#    'familyName': 'Arnoux',
#    'givenName': 'René',
#    'nationality': 'French',
#    'url': 'http://en.wikipedia.org/wiki/Ren%C3%A9_Arnoux'}]}

# %%
#set columns
cols = driver_table['Drivers'][0].keys()

#Empty DataFrame
train = pd.DataFrame(columns=cols)

#Create a Drivers DataFrame
for i in driver_table['Drivers']:
  df = pd.DataFrame([i])[cols]
  if train.empty:
    train = df
  else:
    train = train.append(df)

train
# Out:
#          driverId  ...    nationality
# 0           abate  ...        Italian
# 0       abecassis  ...        British
# 0         acheson  ...        British
# 0           adams  ...        Belgian
# 0            ader  ...       American
# 0          adolff  ...         German
# 0      agabashian  ...       American
# 0          ahrens  ...         German
# 0          aitken  ...        British
# 0          albers  ...          Dutch
# 0           albon  ...           Thai
# 0        alboreto  ...        Italian
# 0           alesi  ...         French
# 0     alguersuari  ...        Spanish
# 0          alliot  ...         French
# 0         allison  ...        British
# 0          alonso  ...        Spanish
# 0           amati  ...        Italian
# 0           amick  ...       American
# 0    george_amick  ...       American
# 0            amon  ...  New Zealander
# 0        anderson  ...        British
# 0       andersson  ...        Swedish
# 0        andretti  ...       American
# 0  mario_andretti  ...       American
# 0         andrews  ...       American
# 0        apicella  ...        Italian
# 0            armi  ...       American
# 0          arnold  ...       American
# 0          arnoux  ...         French
#
# [30 rows x 6 columns]
